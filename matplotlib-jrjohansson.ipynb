# %% [markdown]
# ## Matplotlib lecture
#
#
# Based mostly on:
# https://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb
# http://github.com/jrjohansson/scientific-python-lectures

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# don't display plots in new windows:
# %matplotlib inline

# %%
x = np.linspace(0,5,11); x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2

# %% [markdown]
# ---
#
# Using the **MATLAB-like** plotting API (on just this one plot; OO from then on)

# %%
plt.figure()
plt.plot(x, y, 'r')
plt.xlabel('X'); plt.ylabel('Y'); plt.title('Hi')
plt.show()

# %% [markdown]
# ---
# ### Object-oriented API

# %%
fig1 = plt.figure()
axes = fig1.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom; width, height
axes.plot(x,y)
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Hi')
# Out:
# Text(0.5, 1.0, 'Hi')

# %%
fig2 = plt.figure()

axes1 = fig2.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig2.add_axes([0.2, 0.55, 0.4, 0.3]) # inset axes

# main fig.
axes1.plot(x,y,'r')
axes1.set_xlabel('X')
axes1.set_ylabel('Y')

# inset
axes2.plot(y,x,'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x');

# %% [markdown]
# Using a axis layout manager

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'r')
axes.set_xlabel('X')
axes.set_ylabel('Y');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x,y,'r')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    
fig.tight_layout()

# %%
fig = plt.figure(figsize=(10,3), dpi=72)
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x,y);
#fig.savefig("test.png", dpi=150)

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, label=r"$y = \alpha^2$") # the "r" stands for "raw" to avoid "\"s triggering escapes
ax.plot(x, x**3, '--', label=r"$y = \alpha^3$") 
ax.legend(loc=0) # (loc=9) for top center, (loc=2) for upper left corner, etc.
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel("y")
ax.set_title("Two curves");

# %%
fig, ax = plt.subplots()
ax.plot(x, x+1, color="blue", linewidth=0.5, linestyle="-")
ax.plot(x, x+2, color="blue",        lw=1.0,        ls="--")
ax.plot(x, x+3, color="blue",        lw=2.0,        ls=":")
ax.plot(x, x+4, color="blue",        lw=3.0,        ls="-.") 
ax.plot(x, x+5, c="green", lw=2, ls="--", marker="s", markersize=8, markerfacecolor="red", markeredgewidth=2, markeredgecolor="black")
ax.plot(x, x+6, c="orange",   lw=2, ls="-",  marker="o", ms=10, mfc="yellow", mew=3, mec="green")

# %% [markdown]
# # Plots settings by Manuel Schrauth
# plt.rcParams['axes.linewidth'] = 0.7
# plt.rcParams['font.family'] = 'serif'
# plt.rcParams['font.size'] = 9
# plt.rcParams['axes.labelsize'] = 9
# plt.rcParams['legend.fontsize'] = 8
# plt.rcParams['xtick.labelsize'] = 8
# plt.rcParams['ytick.labelsize'] = 8
# #plt.rcParams['figure.constrained_layout.use'] = True
# plt.rcParams['text.usetex'] = True
# #plt.rcParams['text.latex.preamble'] = '\usepackage{lmodern}'
# inches_per_pt = 1.0/72.27
# width = 200.0*inches_per_pt #246.0

# %% [markdown]
# fig20 = plt.figure(figsize=(width, width/1.57), dpi=150)
# axes = fig20.add_axes([0, 0, 1, 1]) # left, bottom; width, height
# axes.plot(x,y)
# axes.set_xlabel('$x$')
# axes.set_ylabel('$y$')
# axes.set_title('Hi');
# ##plt.tight_layout(pad=0)
# #plt.savefig("fig.pdf",bbox_inches='tight')
